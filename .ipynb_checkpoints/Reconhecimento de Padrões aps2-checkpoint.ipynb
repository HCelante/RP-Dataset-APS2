# %%
import numpy as np
import os

from sklearn import svm

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OutputCodeClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from scipy.signal import welch
from sklearn.metrics import (brier_score_loss, precision_score, recall_score,f1_score)

import matplotlib.pyplot as plt

# %%
from scipy import signal


def butter_bandpass(data, lowcut, highcut, fs=200, order=4):
    nyq = fs * 0.5
    low = lowcut / nyq
    high = highcut / nyq
    b, a = signal.butter(order, [low, high], btype='bandpass')
    return signal.filtfilt(b, a, data)


def butter_lowpass(data, lowcut, fs=200, order=4):
    nyq = fs * 0.5
    low = lowcut / nyq
    b, a = signal.butter(order, low, btype='lowpass')
    return signal.filtfilt(b, a, data)


def butter_highpass(data, highcut, fs=200, order=4):
    nyq = fs * 0.5
    high = highcut / nyq
    b, a = signal.butter(order, high, btype='highpass')
    return signal.filtfilt(b, a, data)


def butter_notch(data, cutoff, var=1, fs=200, order=4):
    nyq = fs * 0.5
    low = (cutoff - var) / nyq
    high = (cutoff + var) / nyq
    b, a = signal.iirfilter(order, [low, high], btype='bandstop', ftype="butter")
    return signal.filtfilt(b, a, data)

# %% [markdown]
# ## Carregando o Dataset

# %%
caminhos = [os.path.join("src", nome) for nome in os.listdir("src")]
print(caminhos)
# Out:
# ['src/1_EMG_Danilo_02-12-2019_201252.npy', 'src/1_EMG_Danilo_02-12-2019_201433.npy', 'src/1_EMG_Danilo_02-12-2019_201601.npy']

# %%
dataset = [np.load(gesture) for gesture in caminhos]
dataset = np.array(dataset)

dataset = dataset.swapaxes(2,3)
dataset = dataset.swapaxes(0,2)
dataset = dataset.reshape(4,5, 3*2000)
dataset = dataset.swapaxes(0,1)
print(dataset.shape)
# Out:
# (5, 4, 6000)

# %% [markdown]
# #### Após o carregamento do dataset, foi realizado a concatenação das tentativas com os dados de cada coleta, resultando no shape:
#
#
# #### (Gesto x eletrodos x dados)

# %% [markdown]
# ## Classificador

# %%
def vaiSVC(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, shuffle=True)


    for kernel in ['rbf']:#, 'linear']:
        for gamma in [0.001, 0.01, 0.1]:
            for C in [1, 10, 100, 1000]:
                classificador = []
                classificador = svm.SVC(gamma=gamma, C=C, kernel=kernel).fit(X_train, y_train)
                print('acuracia:', (classificador.score(X_test, y_test)) * 100, 'kernel:', kernel, 'gamma:', gamma, 'C:', C)
            

    #cls = []
    #cls = LinearDiscriminantAnalysis(solver='lsqr', shrinkage='auto', n_components=7).fit(X_train, y_train)
    #print('\n acuracia:', cls.score(X_test, y_test) * 100)

# %% [markdown]
# ## Plotting

# %%
def filtering (dataset):
    
    
    for i in range(dataset.shape[1]):
        plt.plot(dataset[0,i,:])
    plt.show()
    data_filtered = []
    #print(dataset.shape[i])
    print(dataset.shape)
    
    data_filtered = butter_notch(dataset, 60)
    for i in range(data_filtered.shape[1]):
        plt.plot(data_filtered[0,i,:])
    plt.show()
    
    data_filtered = butter_highpass(data_filtered, 5)
    for i in range(data_filtered.shape[1]):
        plt.plot(data_filtered[0,i,:])
    plt.show()
    
    data_filtered = butter_lowpass(data_filtered, 50)
    for i in range(data_filtered.shape[1]):
        plt.plot(data_filtered[0,i,:])
    plt.show()
    
    return data_filtered

# %% [markdown]
# ### Para diminuir o ruído dos dados foi aplicado os filtros Notch, Highpass e LowPass.

# %%
data_filtered = filtering(dataset)
# Out:
# (5, 4, 6000)

# %%
print(data_filtered.shape)
# Out:
# (5, 4, 6000)

# %% [markdown]
# ## Segmentação
# ### Na segmentação foram definidos segmentos com o tamanho de 129 e saltos de 20, tendo assim 109 pontos de sobreposição.

# %%
salto = 20
segmento = 129
print(data_filtered.shape)
n_win = int((data_filtered.shape[-1] - segmento) / salto) + 1
ids = np.arange(n_win) * salto
x = np.array([data_filtered[:,:,k:(k + segmento)] for k in ids]).transpose(1, 2, 0, 3)
print(x.shape)
# Out:
# (5, 4, 6000)
# (5, 4, 294, 129)

# %% [markdown]
# ## Extração de Características
#
# Para realização da classificação dos movimentos foi necessário extrair características tanto no domínio do tempo quanto no domínio da frequência.

# %% [markdown]
# ## Domínio do Tempo

# %% [markdown]
# #### IEMG

# %%
#mod = np.positive(x)
iemg =  np.sum(np.abs(x), axis=-1) / 129
print(iemg.shape)

for i in range(iemg.shape[1]):
    plt.plot(iemg[3,i,:])
plt.show()
# Out:
# (5, 4, 294)

# %% [markdown]
# #### VAR

# %%
var = np.sum(x ** 2, axis=-1) / (np.prod(x.shape[:-1]) - 1)
print(var.shape)

for i in range(var.shape[1]):
    plt.plot(var[3,i,:])
plt.show()
# Out:
# (5, 4, 294)

# %% [markdown]
# #### RMS

# %%
rms = np.sqrt(np.sum(np.abs(x) ** 2, axis=-1) / (np.prod(x.shape[:-1]) - 1))
print(rms.shape)

for i in range(rms.shape[1]):
    plt.plot(rms[3,i,:])
plt.show()
# Out:
# (5, 4, 294)

# %% [markdown]
# ### Criando Vetor de Labels
#
# Foram concatenadas as características no domínio do tempo com os eletrodos e os segmentos, resultando no shape:
# (características , gestos)

# %%
lista = [rms] + [var] + [iemg]
lista = np.array(lista)
lista = lista.swapaxes(0,1)
lista = lista.reshape(5,3* 4*294)
lista = lista.swapaxes(0,1)
lista = lista[:,:][:3525]
print(lista.shape)
# Out:
# (3525, 5)

# %%
y = np.array([[str(i)] * int(lista.shape[0] / 5) for i in range(5)])
y = y.reshape(y.shape[0] * y.shape[1])
y.shape
# Out:
# (3525,)

# %%
vaiSVC(lista,y)
# Out:
# acuracia: 60.49645390070923 kernel: rbf gamma: 0.001 C: 1
# acuracia: 64.7517730496454 kernel: rbf gamma: 0.001 C: 10
# acuracia: 72.90780141843972 kernel: rbf gamma: 0.001 C: 100
# acuracia: 81.84397163120568 kernel: rbf gamma: 0.001 C: 1000
# acuracia: 69.57446808510637 kernel: rbf gamma: 0.01 C: 1
# acuracia: 80.42553191489363 kernel: rbf gamma: 0.01 C: 10
# acuracia: 88.01418439716312 kernel: rbf gamma: 0.01 C: 100
# acuracia: 88.51063829787233 kernel: rbf gamma: 0.01 C: 1000
# acuracia: 87.80141843971631 kernel: rbf gamma: 0.1 C: 1
# acuracia: 89.7872340425532 kernel: rbf gamma: 0.1 C: 10
# acuracia: 90.28368794326241 kernel: rbf gamma: 0.1 C: 100
# acuracia: 92.34042553191489 kernel: rbf gamma: 0.1 C: 1000

# %% [markdown]
# # Domínio da Frequência

# %%
from scipy.signal import stft

print(data_filtered.shape)
_, _, w = stft(data_filtered, fs=200, nperseg=256, noverlap=32)
w = w.swapaxes(2,3)
print(w.shape)
# Out:
# (5, 4, 6000)
# (5, 4, 28, 129)

# %% [markdown]
# #### PSD

# %%
def PSD(x):
    return np.sqrt(np.abs(x))

# %% [markdown]
# #### FMD

# %%
fmd = np.sum(PSD(w), axis=-1) / 2
print(fmd.shape)
# Out:
# (5, 4, 28)

# %% [markdown]
# #### MMDF

# %%
mmdf = np.sum(np.abs(w), axis=-1) / 2
print(mmdf.shape)
# Out:
# (5, 4, 28)

# %%
frelist = [fmd] + [mmdf]
frelist = np.array(frelist)
frelist = frelist.swapaxes(0,1)
frelist = frelist.reshape(5,2*4*28)
frelist = frelist.swapaxes(0,1)
frelist = frelist[:][:220]
print(frelist.shape)
# Out:
# (220, 5)

# %%
y2 = np.array([[str(i)] * int(frelist.shape[0] / 5) for i in range(5)])
y2 = y2.reshape(y2.shape[0] * y2.shape[1])
y2.shape
# Out:
# (220,)

# %%
vaiSVC(frelist,y2)
# Out:
# acuracia: 72.72727272727273 kernel: rbf gamma: 0.001 C: 1
# acuracia: 80.68181818181817 kernel: rbf gamma: 0.001 C: 10
# acuracia: 69.31818181818183 kernel: rbf gamma: 0.001 C: 100
# acuracia: 64.77272727272727 kernel: rbf gamma: 0.001 C: 1000
# acuracia: 75.0 kernel: rbf gamma: 0.01 C: 1
# acuracia: 70.45454545454545 kernel: rbf gamma: 0.01 C: 10
# acuracia: 68.18181818181817 kernel: rbf gamma: 0.01 C: 100
# acuracia: 68.18181818181817 kernel: rbf gamma: 0.01 C: 1000
# acuracia: 55.68181818181818 kernel: rbf gamma: 0.1 C: 1
# acuracia: 61.36363636363637 kernel: rbf gamma: 0.1 C: 10
# acuracia: 61.36363636363637 kernel: rbf gamma: 0.1 C: 100
# acuracia: 61.36363636363637 kernel: rbf gamma: 0.1 C: 1000

# %% [markdown]
# # Combinação domínio do tempo e frequência

# %%
print(lista.shape)
print(frelist.shape)

X = np.concatenate((lista, frelist), axis=0)
yf = np.concatenate((y2 , y), axis=0)
print(y2.shape, y.shape)
print(yf.shape)
print(X.shape)
# Out:
# (3525, 5)
# (220, 5)
# (220,) (3525,)
# (3745,)
# (3745, 5)

# %%
vaiSVC(X,yf)
# Out:
# acuracia: 65.48731642189586 kernel: rbf gamma: 0.001 C: 1
# acuracia: 72.6969292389853 kernel: rbf gamma: 0.001 C: 10
# acuracia: 74.6995994659546 kernel: rbf gamma: 0.001 C: 100
# acuracia: 80.70761014686248 kernel: rbf gamma: 0.001 C: 1000
# acuracia: 75.76769025367156 kernel: rbf gamma: 0.01 C: 1
# acuracia: 81.04138851802402 kernel: rbf gamma: 0.01 C: 10
# acuracia: 84.77970627503338 kernel: rbf gamma: 0.01 C: 100
# acuracia: 85.78104138851802 kernel: rbf gamma: 0.01 C: 1000
# acuracia: 84.71295060080108 kernel: rbf gamma: 0.1 C: 1
# acuracia: 88.25100133511349 kernel: rbf gamma: 0.1 C: 10
# acuracia: 89.85313751668892 kernel: rbf gamma: 0.1 C: 100
# acuracia: 90.72096128170895 kernel: rbf gamma: 0.1 C: 1000
